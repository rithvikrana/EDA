# %%
import seaborn as sns

# %%
df=sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())

# %%
sns.jointplot(x="tip",y="total_bill",data=df,kind="hex")

# %%
sns.jointplot(x="tip",y="total_bill",data=df,kind="reg")

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue="smoker")

# %%
df["smoker"].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.distplot(df['tip'])

# %%
sns.distplot(df['tip'],bins=10,kde=False)

# %%
sns.countplot('day',data=df)

# %%
sns.countplot(y='sex',data=df)

# %%
sns.barplot(x="total_bill",y="day",data=df)

# %%
sns.barplot(y="total_bill",x="day",data=df)

# %%
sns.boxplot("sex","total_bill",data=df)

# %%
sns.boxplot("sex","total_bill",data=df,palette="rainbow")

# %%
sns.boxplot(data=df,orient='v')

# %%
sns.boxplot(y="sex",x="total_bill",hue="day",data=df,palette="rainbow")

# %%
sns.violinplot(y="sex",x="total_bill",hue="day",data=df,palette="rainbow")
